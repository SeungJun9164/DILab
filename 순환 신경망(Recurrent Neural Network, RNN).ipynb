# %%
import torch
import torch.nn as nn

# %%
input_size = 5
hidden_size = 8

# %%
inputs = torch.Tensor(1, 10, 5) # (batch_size, time_steps, input_size)

# %%
cell = nn.RNN(input_size, hidden_size, batch_first=True) # batch_first : 입력 텐서의 첫번째 차원이 배치 크기임을 알려줌

# %%
# outputs : 모든 시점의 은닉상태들
# _status : 마지막 시점의 은닉상태
outputs, _status = cell(inputs)

# %%
print(outputs.shape) # 10번의 시점동안 8차원 은닉상태가 출력
# Out:
# torch.Size([1, 10, 8])

# %%
print(_status.shape)
# Out:
# torch.Size([1, 1, 8])

# %% [markdown]
# # Deep Recurrent Neural

# %%
inputs = torch.Tensor(1, 10, 5)

# %%
cell = nn.RNN(input_size = 5, hidden_size = 8, num_layers = 2, batch_first = True) # num_layers : 층

# %%
outputs, _status = cell(inputs)

# %%
print(outputs.shape)
# Out:
# torch.Size([1, 10, 8])

# %%
print(_status.shape) # 층의 갯수, 배치크기, 은닉상태크기
# Out:
# torch.Size([2, 1, 8])

# %% [markdown]
# # 양방향 순환 신경망(Bidirectional Recurrent Neural Network)

# %%
inputs = torch.Tensor(1, 10, 5)

# %%
cell = nn.RNN(input_size = 5, hidden_size = 8, num_layers = 2, batch_first=True, bidirectional = True)
# bidirectional : 양방향 설정

# %%
outputs, _status = cell(inputs)

# %%
print(outputs.shape)
# Out:
# torch.Size([1, 10, 16])

# %%
print(_status.shape)
# Out:
# torch.Size([4, 1, 8])
