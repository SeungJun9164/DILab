# %%
import pandas as pd

# %%
columns = ['id', 'text', 'label']

train_data = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt', sep='\t', names=columns, skiprows=1).dropna()
test_data = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt', sep='\t', names=columns, skiprows=1).dropna()

# %%
train_data.to_csv('C:\\Users\\abc\\jupyter\\pytorch\\Sentiment_analysis\\train_data.csv', index = False)
test_data.to_csv('C:\\Users\\abc\\jupyter\\pytorch\\Sentiment_analysis\\test_data.csv', index = False)

# %%
import torch
from torchtext import data

# %%
SEED = 1234

torch.manual_seed(SEED)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device == 'cuda':
    torch.cuda.manual_seed(SEED)

# %%
from eunjeon import Mecab
mecab = Mecab()

# %%
# include_lengths : 패딩 된 미니 배치의 튜플과 각 예제의 길이가 포함 된 목록을 반환할지 아니면 패딩 된 미니 배치 만 반환할지 여부
TEXT = data.Field(tokenize=mecab.morphs, include_lengths=True)
LABEL = data.LabelField(dtype=torch.float)

# %%
fields = {'text':('text',TEXT), 'label':('label',LABEL)}

# %%
train_data, test_data = data.TabularDataset.splits(
    path ='C:\\Users\\abc\\jupyter\\pytorch\\Sentiment_analysis',
    train = 'train_data.csv',
    test = 'test_data.csv',
    format = 'csv',
    fields = fields)

# %%
import random

train_data, valid_data = train_data.split(random_state = random.seed(SEED))

# %%
MAX_VOCAB_SIZE = 25000

# fasttext.simple.300d : 사전 훈련된 임베딩 벡터 / unk_itit : 사전훈련된 단어집에 없는 단어는 0으로 처리하는 것을 방지하기 위해
TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE, vectors = 'fasttext.simple.300d', unk_init=torch.Tensor.normal_)
LABEL.build_vocab(train_data)
# Out:
# .vector_cache\wiki.simple.vec: 293MB [00:30, 9.72MB/s]
#   0%|                                                                                       | 0/111051 [00:00<?, ?it/s]Skipping token b'111051' with 1-dimensional vector [b'300']; likely a header
# 100%|███████████████████████████████████████████████████████████████████████| 111051/111051 [00:10<00:00, 10238.91it/s]

# %%
len(TEXT.vocab)
# Out:
# 25002

# %%
LABEL.vocab.stoi
# Out:
# defaultdict(None, {'0': 0, '1': 1})

# %%
TEXT.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x0000023B8E7F2460>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              '.': 2,
#              '이': 3,
#              '는': 4,
#              '영화': 5,
#              '다': 6,
#              '고': 7,
#              '하': 8,
#              '도': 9,
#              '의': 10,
#              '가': 11,
#              '은': 12,
#              '에': 13,
#              '을': 14,
#              '한': 15,
#              '보': 16,
#              '..': 17,
#              '게': 18,
#              ',': 19,
#              '들': 20,
#              '!': 21,
#              '지': 22,
#              '를': 23,
#              '있': 24,
#              '없': 25,
#              '?': 26,
#              '좋': 27,
#              '나': 28,
#              '었': 29,
#              '만': 30,
#              '는데': 31,
#              '너무': 32,
#              '적': 33,
#              '봤': 34,
#              '안': 35,
#              '로': 36,
#              '정말': 37,
#              '음': 38,
#              '으로': 39,
#              '것': 40,
#              '아': 41,
#              '네요': 42,
#              '재밌': 43,
#              '어': 44,
#              '점': 45,
#              '같': 46,
#              '진짜': 47,
#              '지만': 48,
#              '했': 49,
#              '에서': 50,
#              '기': 51,
#              '않': 52,
#              '네': 53,
#              '거': 54,
#              '았': 55,
#              '수': 56,
#              '되': 57,
#              'ㅋㅋ': 58,
#              '면': 59,
#              '과': 60,
#              '인': 61,
#              '말': 62,
#              '연기': 63,
#              '최고': 64,
#              '잘': 65,
#              '주': 66,
#              '~': 67,
#              '내': 68,
#              '평점': 69,
#              '어요': 70,
#              '던': 71,
#              '이런': 72,
#              '와': 73,
#              '생각': 74,
#              '할': 75,
#              'ㅋㅋㅋ': 76,
#              '1': 77,
#              '해': 78,
#              '스토리': 79,
#              '겠': 80,
#              '왜': 81,
#              '습니다': 82,
#              '...': 83,
#              '드라마': 84,
#              '아니': 85,
#              '싶': 86,
#              '그': 87,
#              '듯': 88,
#              '사람': 89,
#              '함': 90,
#              '때': 91,
#              '감동': 92,
#              '더': 93,
#              '배우': 94,
#              '까지': 95,
#              '본': 96,
#              '좀': 97,
#              '뭐': 98,
#              '지루': 99,
#              '볼': 100,
#              '보다': 101,
#              '알': 102,
#              '만들': 103,
#              '내용': 104,
#              '감독': 105,
#              '라': 106,
#              '재미있': 107,
#              '재미': 108,
#              '그냥': 109,
#              '중': 110,
#              '시간': 111,
#              '년': 112,
#              '10': 113,
#              '잼': 114,
#              '재미없': 115,
#              '였': 116,
#              '쓰레기': 117,
#              '사랑': 118,
#              '못': 119,
#              '냐': 120,
#              '서': 121,
#              '야': 122,
#              '2': 123,
#              '니': 124,
#              '라고': 125,
#              '다시': 126,
#              '면서': 127,
#              '하나': 128,
#              '나오': 129,
#              '번': 130,
#              '작품': 131,
#              '이거': 132,
#              '줄': 133,
#              '해서': 134,
#              '마지막': 135,
#              '남': 136,
#              '개': 137,
#              '정도': 138,
#              '임': 139,
#              'ㅋ': 140,
#              '끝': 141,
#              '액션': 142,
#              '이건': 143,
#              '3': 144,
#              '건': 145,
#              '입니다': 146,
#              '완전': 147,
#              '라는': 148,
#              '많': 149,
#              '기대': 150,
#              '다는': 151,
#              '장면': 152,
#              '아깝': 153,
#              '분': 154,
#              '처음': 155,
#              '참': 156,
#              '대': 157,
#              '으면': 158,
#              '다가': 159,
#              '이렇게': 160,
#              '지금': 161,
#              "'": 162,
#              '이게': 163,
#              '모르': 164,
#              '일': 165,
#              '편': 166,
#              '성': 167,
#              '최악': 168,
#              '돈': 169,
#              '이야기': 170,
#              '느낌': 171,
#              '님': 172,
#              '시': 173,
#              '된': 174,
#              '자': 175,
#              '봐도': 176,
#              '어서': 177,
#              '별로': 178,
#              '넘': 179,
#              '다고': 180,
#              '애': 181,
#              '걸': 182,
#              '인데': 183,
#              '그리고': 184,
#              'ㅠㅠ': 185,
#              '난': 186,
#              '한국': 187,
#              '^^': 188,
#              '역시': 189,
#              '또': 190,
#              '명작': 191,
#              '부터': 192,
#              '여자': 193,
#              '이해': 194,
#              '에게': 195,
#              '전': 196,
#              '는지': 197,
#              '많이': 198,
#              '주인공': 199,
#              '이상': 200,
#              '합니다': 201,
#              '!!': 202,
#              '받': 203,
#              '두': 204,
#              '우리': 205,
#              '엔': 206,
#              '괜찮': 207,
#              '만든': 208,
#              '살': 209,
#              '기억': 210,
#              '길': 211,
#              '저': 212,
#              '연출': 213,
#              '이나': 214,
#              '재': 215,
#              'ㅎㅎ': 216,
#              '때문': 217,
#              '한다': 218,
#              '꼭': 219,
#              '요': 220,
#              '며': 221,
#              '긴': 222,
#              '죽': 223,
#              '현실': 224,
#              '결말': 225,
#              '랑': 226,
#              '무슨': 227,
#              '별': 228,
#              'ㅡㅡ': 229,
#              '내내': 230,
#              '남자': 231,
#              '굿': 232,
#              '마음': 233,
#              '속': 234,
#              '세요': 235,
#              '소재': 236,
#              '공포': 237,
#              '짱': 238,
#              '아서': 239,
#              '전개': 240,
#              '은데': 241,
#              '다른': 242,
#              '인생': 243,
#              '뿐': 244,
#              '씨': 245,
#              '유치': 246,
#              '없이': 247,
#              '~~': 248,
#              '오': 249,
#              '필요': 250,
#              '반전': 251,
#              '아요': 252,
#              '아이': 253,
#              '짜증': 254,
#              ';;': 255,
#              '음악': 256,
#              '가장': 257,
#              ')': 258,
#              '수준': 259,
#              'ㄷ': 260,
#              '밋': 261,
#              '낮': 262,
#              '가슴': 263,
#              '웃': 264,
#              '일본': 265,
#              '맞': 266,
#              '매력': 267,
#              'ㅠ': 268,
#              '다니': 269,
#              '몰입': 270,
#              '데': 271,
#              '높': 272,
#              '인지': 273,
#              '급': 274,
#              '인간': 275,
#              '원작': 276,
#              '(': 277,
#              '만드': 278,
#              '준': 279,
#              '눈물': 280,
#              '신': 281,
#              '인가': 282,
#              '마': 283,
#              '보여': 284,
#              '을까': 285,
#              '노': 286,
#              '용': 287,
#              '여': 288,
#              '자체': 289,
#              '찍': 290,
#              '울': 291,
#              '4': 292,
#              '모든': 293,
#              '코미디': 294,
#              '추천': 295,
#              '5': 296,
#              '쓰': 297,
#              '아직': 298,
#              '화': 299,
#              '대박': 300,
#              '아닌': 301,
#              '눈': 302,
#              '처럼': 303,
#              '스럽': 304,
#              '는다': 305,
#              '대한': 306,
#              '란': 307,
#              '캐릭터': 308,
#              '솔직히': 309,
#              '-': 310,
#              '실망': 311,
#              '여운': 312,
#              '그런': 313,
#              '죠': 314,
#              '몇': 315,
#              'ㅎ': 316,
#              '아주': 317,
#              '건지': 318,
#              '모두': 319,
#              '전혀': 320,
#              '나라': 321,
#              '가족': 322,
#              '뭔가': 323,
#              '연기력': 324,
#              '작': 325,
#              '후': 326,
#              '시리즈': 327,
#              '될': 328,
#              '그래도': 329,
#              '다면': 330,
#              '""': 331,
#              '제': 332,
#              '근데': 333,
#              '공감': 334,
#              '개봉': 335,
#              '작가': 336,
#              '먹': 337,
#              '밖에': 338,
#              '비': 339,
#              ';': 340,
#              '진': 341,
#              '표현': 342,
#              '제목': 343,
#              '7': 344,
#              '대단': 345,
#              '모습': 346,
#              '이랑': 347,
#              '계속': 348,
#              '극장': 349,
#              '0': 350,
#              '그렇': 351,
#              '아쉽': 352,
#              '어디': 353,
#              '대사': 354,
#              '보고': 355,
#              '바': 356,
#              '부분': 357,
#              '억지': 358,
#              'OO': 359,
#              '물': 360,
#              '이걸': 361,
#              '감': 362,
#              '해도': 363,
#              '웃기': 364,
#              '보이': 365,
#              '막장': 366,
#              '기분': 367,
#              '놓': 368,
#              '치': 369,
#              '봐야': 370,
#              '구': 371,
#              '친구': 372,
#              '"': 373,
#              '....': 374,
#              '진심': 375,
#              '아까운': 376,
#              '된다': 377,
#              '씬': 378,
#              '타임': 379,
#              '요즘': 380,
#              '가지': 381,
#              '노래': 382,
#              '딱': 383,
#              '삶': 384,
#              '이제': 385,
#              '싫': 386,
#              '라도': 387,
#              '믿': 388,
#              '잔잔': 389,
#              '구나': 390,
#              '스릴러': 391,
#              '나왔': 392,
#              '이유': 393,
#              '조금': 394,
#              '찾': 395,
#              '점수': 396,
#              '긴장감': 397,
#              '영상': 398,
#              '제대로': 399,
#              '잇': 400,
#              '8': 401,
#              '날': 402,
#              '라면': 403,
#              '아름다운': 404,
#              '같이': 405,
#              '개인': 406,
#              '/': 407,
#              '시대': 408,
#              '만큼': 409,
#              '부족': 410,
#              '차라리': 411,
#              '제일': 412,
#              '중간': 413,
#              '시작': 414,
#              'ㅜㅜ': 415,
#              '한테': 416,
#              '무섭': 417,
#              '어떻게': 418,
#              '이것': 419,
#              '나름': 420,
#              '당시': 421,
#              '의미': 422,
#              '사': 423,
#              '던데': 424,
#              '특히': 425,
#              '오랜만': 426,
#              '세상': 427,
#              '하지만': 428,
#              '명': 429,
#              '해요': 430,
#              '려고': 431,
#              '세': 432,
#              '엔딩': 433,
#              '절대': 434,
#              '니까': 435,
#              '팬': 436,
#              '욕': 437,
#              '봐': 438,
#              '강추': 439,
#              '못하': 440,
#              '봄': 441,
#              '9': 442,
#              '훌륭': 443,
#              '해야': 444,
#              '빼': 445,
#              '그저': 446,
#              '신선': 447,
#              '너무나': 448,
#              '나온': 449,
#              '답답': 450,
#              '따뜻': 451,
#              '느끼': 452,
#              '준다': 453,
#              '어야': 454,
#              '글': 455,
#              '수작': 456,
#              '만화': 457,
#              '됨': 458,
#              '설정': 459,
#              'OOO': 460,
#              '감정': 461,
#              '무엇': 462,
#              'ㅡ': 463,
#              '전쟁': 464,
#              '어도': 465,
#              '흥미': 466,
#              '마다': 467,
#              '시절': 468,
#              '뻔': 469,
#              '도대체': 470,
#              '6': 471,
#              '미국': 472,
#              '캐스팅': 473,
#              '행복': 474,
#              '드': 475,
#              '허접': 476,
#              '놈': 477,
#              '슬프': 478,
#              '앞': 479,
#              '형': 480,
#              '군': 481,
#              '추억': 482,
#              '소름': 483,
#              '류': 484,
#              '엄청': 485,
#              '더라': 486,
#              '첨': 487,
#              '사실': 488,
#              '질': 489,
#              '초반': 490,
#              '힘들': 491,
#              '어색': 492,
#              '관객': 493,
#              '시나리오': 494,
#              '웃음': 495,
#              '라니': 496,
#              '오늘': 497,
#              '문제': 498,
#              '배경': 499,
#              '멋진': 500,
#              '정신': 501,
#              '구성': 502,
#              '걍': 503,
#              '머': 504,
#              '봐서': 505,
#              '졸작': 506,
#              '잡': 507,
#              '뻔한': 508,
#              '위해': 509,
#              '엄마': 510,
#              '나요': 511,
#              '답': 512,
#              '분위기': 513,
#              '멋있': 514,
#              '뭔': 515,
#              '역사': 516,
#              '완벽': 517,
#              '자신': 518,
#              '낫': 519,
#              '20': 520,
#              '결국': 521,
#              '함께': 522,
#              '등': 523,
#              '소리': 524,
#              '잊': 525,
#              '난다': 526,
#              '어떤': 527,
#              '어이없': 528,
#              '뭘': 529,
#              '얼마나': 530,
#              '영화관': 531,
#              '포스터': 532,
#              '아무리': 533,
#              '후회': 534,
#              '애니메이션': 535,
#              '코믹': 536,
#              '집': 537,
#              '한데': 538,
#              '됐': 539,
#              '!!!': 540,
#              '제발': 541,
#              '유쾌': 542,
#              '간': 543,
#              '나올': 544,
#              '어릴': 545,
#              '더니': 546,
#              '스러운': 547,
#              '러': 548,
#              '킬링': 549,
#              '평가': 550,
#              'ㅅ': 551,
#              '주연': 552,
#              '원': 553,
#              '~~~': 554,
#              '엇': 555,
#              '장난': 556,
#              '진부': 557,
#              '버리': 558,
#              '큰': 559,
#              '둘': 560,
#              '자기': 561,
#              '출연': 562,
#              '보단': 563,
#              '얼굴': 564,
#              '맘': 565,
#              '매우': 566,
#              '♥': 567,
#              '깊': 568,
#              '배': 569,
#              '이딴': 570,
#              '옛날': 571,
#              '이리': 572,
#              '갈수록': 573,
#              '꽤': 574,
#              '봐라': 575,
#              '충격': 576,
#              '개연': 577,
#              '극': 578,
#              '예술': 579,
#              '라서': 580,
#              '으나': 581,
#              '낭비': 582,
#              '동안': 583,
#              '미': 584,
#              '이쁘': 585,
#              '잔인': 586,
#              '책': 587,
#              '크': 588,
#              '순수': 589,
#              '시청': 590,
#              '예전': 591,
#              '이후': 592,
#              '+': 593,
#              '미친': 594,
#              '든': 595,
#              '건가': 596,
#              '궁금': 597,
#              '꺼': 598,
#              '별점': 599,
#              '상황': 600,
#              '여기': 601,
#              '겟': 602,
#              '위한': 603,
#              '감사': 604,
#              '아름답': 605,
#              '줬': 606,
#              '텐데': 607,
#              '장르': 608,
#              '그래서': 609,
#              '머리': 610,
#              '못한': 611,
#              '얘기': 612,
#              '그렇게': 613,
#              '다큐': 614,
#              '언제': 615,
#              '누구': 616,
#              '다운': 617,
#              '시키': 618,
#              '아무': 619,
#              '오래': 620,
#              ':': 621,
#              '꿈': 622,
#              '대체': 623,
#              '비디오': 624,
#              '애니': 625,
#              '다음': 626,
#              '그나마': 627,
#              '더빙': 628,
#              '약간': 629,
#              '뒤': 630,
#              '무': 631,
#              '읽': 632,
#              '어느': 633,
#              '인상': 634,
#              '아님': 635,
#              '시즌': 636,
#              '불쌍': 637,
#              '이름': 638,
#              '그러': 639,
#              '그만': 640,
#              'B': 641,
#              '??': 642,
#              '떨어지': 643,
#              '주제': 644,
#              '티비': 645,
#              '식': 646,
#              '너': 647,
#              '반': 648,
#              '스릴': 649,
#              '엉성': 650,
#              '집중': 651,
#              '케': 652,
#              '든다': 653,
#              '죽이': 654,
#              '로맨스': 655,
#              '실화': 656,
#              '까': 657,
#              '마세요': 658,
#              '귀엽': 659,
#              '났': 660,
#              '만점': 661,
#              '본다': 662,
#              '평': 663,
#              '에요': 664,
#              '왔': 665,
#              '진정': 666,
#              '해라': 667,
#              '감성': 668,
#              '그것': 669,
#              '나와서': 670,
#              '인물': 671,
#              '회': 672,
#              '방송': 673,
#              '짜리': 674,
#              '비슷': 675,
#              '영상미': 676,
#              '힘': 677,
#              '발연기': 678,
#              '상': 679,
#              '여주인공': 680,
#              '존나': 681,
#              '걸작': 682,
#              '전체': 683,
#              '중국': 684,
#              '단': 685,
#              '사회': 686,
#              '어린': 687,
#              '짓': 688,
#              '그대로': 689,
#              '망': 690,
#              '세계': 691,
#              '타': 692,
#              'CG': 693,
#              '누가': 694,
#              '비교': 695,
#              '끝나': 696,
#              '소설': 697,
#              '여배우': 698,
#              '판': 699,
#              '돋': 700,
#              'ㅜ': 701,
#              '대해': 702,
#              '훨씬': 703,
#              '갔': 704,
#              '꿀': 705,
#              '햇': 706,
#              '여주': 707,
#              '더럽': 708,
#              '30': 709,
#              '는가': 710,
#              '달': 711,
#              '순간': 712,
#              '어렸': 713,
#              '려는': 714,
#              '존': 715,
#              '졸': 716,
#              '~!': 717,
#              '구만': 718,
#              '나이': 719,
#              '막': 720,
#              '셨': 721,
#              '어설픈': 722,
#              '초딩': 723,
#              '100': 724,
#              ';;;': 725,
#              '가능': 726,
#              '느껴': 727,
#              '잘못': 728,
#              '삼류': 729,
#              'ㅎㅎㅎ': 730,
#              '쯤': 731,
#              '네이버': 732,
#              '느낄': 733,
#              '나온다': 734,
#              '아들': 735,
#              '혼자': 736,
#              '바로': 737,
#              '이영화': 738,
#              '입': 739,
#              '빨리': 740,
#              '첫': 741,
#              '교훈': 742,
#              '나가': 743,
#              '맛': 744,
#              '아야': 745,
#              '어른': 746,
#              '끌': 747,
#              '영': 748,
#              '한마디': 749,
#              '성룡': 750,
#              '학교': 751,
#              '가치': 752,
#              '딸': 753,
#              '멋지': 754,
#              '당신': 755,
#              '목소리': 756,
#              '땜': 757,
#              '잠': 758,
#              '초': 759,
#              '티': 760,
#              '화려': 761,
#              '.....': 762,
#              '맨': 763,
#              '봤었': 764,
#              '군요': 765,
#              '굳': 766,
#              '률': 767,
#              '불': 768,
#              '으면서': 769,
#              '전부': 770,
#              '길래': 771,
#              '당': 772,
#              '듣': 773,
#              '위': 774,
#              '90': 775,
#              '다르': 776,
#              '아까움': 777,
#              '넣': 778,
#              '스타일': 779,
#              'ㅉㅉ': 780,
#              '갑자기': 781,
#              '그러나': 782,
#              '밑': 783,
#              '아버지': 784,
#              '이번': 785,
#              '각본': 786,
#              '저런': 787,
#              '존재': 788,
#              '독특': 789,
#              '차': 790,
#              '판타지': 791,
#              '평론가': 792,
#              '다만': 793,
#              '줄거리': 794,
#              '허무': 795,
#              '한번': 796,
#              'ㅂ': 797,
#              '담': 798,
#              '여러': 799,
#              '건데': 800,
#              '상당히': 801,
#              '새로운': 802,
#              '화면': 803,
#              '거의': 804,
#              '비해': 805,
#              '평범': 806,
#              '너무너무': 807,
#              '똥': 808,
#              '버린': 809,
#              '생': 810,
#              '앗': 811,
#              '째': 812,
#              '성우': 813,
#              '에선': 814,
#              '예쁘': 815,
#              '예상': 816,
#              '의도': 817,
#              '이러': 818,
#              '질질': 819,
#              '그녀': 820,
#              '제작': 821,
#              'TV': 822,
#              '낸': 823,
#              '만나': 824,
#              '진행': 825,
#              'ㄱ': 826,
#              '돼': 827,
#              '떠나': 828,
#              '스': 829,
#              '씩': 830,
#              '대로': 831,
#              '예요': 832,
#              '일단': 833,
#              '굉장히': 834,
#              '쉽': 835,
#              '자연': 836,
#              '줌': 837,
#              '중요': 838,
#              '버렸': 839,
#              '복수': 840,
#              '아빠': 841,
#              '연출력': 842,
#              '갖': 843,
#              '개그': 844,
#              '산': 845,
#              '단순': 846,
#              '잃': 847,
#              '한심': 848,
#              '댓글': 849,
#              '선택': 850,
#              '조차': 851,
#              '한편': 852,
#              '거기': 853,
#              '요소': 854,
#              '짧': 855,
#              '슬픈': 856,
#              '아닌가': 857,
#              '따': 858,
#              '발': 859,
#              '쓴': 860,
#              '피': 861,
#              '부': 862,
#              '불편': 863,
#              '설명': 864,
#              '%': 865,
#              '~!!': 866,
#              '거나': 867,
#              '던가': 868,
#              '훈훈': 869,
#              '그런지': 870,
#              '롭': 871,
#              '점점': 872,
#              '법': 873,
#              '탄탄': 874,
#              '못했': 875,
#              '사건': 876,
#              '식상': 877,
#              '관람': 878,
#              '그래픽': 879,
#              '전형': 880,
#              '흥행': 881,
#              '려': 882,
#              '미안': 883,
#              '뻔하': 884,
#              '항상': 885,
#              'tv': 886,
#              '귀신': 887,
#              '에겐': 888,
#              '그게': 889,
#              '나옴': 890,
#              '역대': 891,
#              '짐': 892,
#              '편집': 893,
#              '프랑스': 894,
#              '게임': 895,
#              '곳': 896,
#              '극장판': 897,
#              '뭔지': 898,
#              '짜': 899,
#              '총': 900,
#              '한다는': 901,
#              '역': 902,
#              '원래': 903,
#              '장': 904,
#              '그때': 905,
#              '또한': 906,
#              '안타깝': 907,
#              '충분히': 908,
#              '홍콩': 909,
#              '-_-': 910,
#              'good': 911,
#              '도저히': 912,
#              '멋': 913,
#              '물론': 914,
#              '쳐': 915,
#              '구요': 916,
#              '넘치': 917,
#              '이하': 918,
#              '자극': 919,
#              '팔': 920,
#              '도록': 921,
#              '삼': 922,
#              '아까워': 923,
#              '어울리': 924,
#              '80': 925,
#              '김': 926,
#              '됬': 927,
#              '따라': 928,
#              '만족': 929,
#              '자꾸': 930,
#              '중반': 931,
#              '잖아': 932,
#              '죽음': 933,
#              '참신': 934,
#              '했었': 935,
#              '화이팅': 936,
#              '빠': 937,
#              '아프': 938,
#              '풀': 939,
#              '불륜': 940,
#              '손': 941,
#              '어쩔': 942,
#              '진지': 943,
#              '나쁘': 944,
#              '왕': 945,
#              '더욱': 946,
#              '상영': 947,
#              '소중': 948,
#              '인듯': 949,
#              '프로': 950,
#              '과거': 951,
#              '관계': 952,
#              '미치': 953,
#              '황당': 954,
#              'ㄴ': 955,
#              '몰랐': 956,
#              '심하': 957,
#              '척': 958,
#              '결혼': 959,
#              '똑같': 960,
#              '멜': 961,
#              '아도': 962,
#              '좋아하': 963,
#              '코메디': 964,
#              '속편': 965,
#              '숨': 966,
#              '짱짱': 967,
#              '간다': 968,
#              '나쁜': 969,
#              '병맛': 970,
#              '아쉬움': 971,
#              'ost': 972,
#              '괜히': 973,
#              '대작': 974,
#              '동화': 975,
#              '엄청난': 976,
#              '고자': 977,
#              '느꼈': 978,
#              '순': 979,
#              '유명': 980,
#              '헐': 981,
#              '닿': 982,
#              '연기자': 983,
#              '쩔': 984,
#              '그닥': 985,
#              '그림': 986,
#              '별루': 987,
#              '심리': 988,
#              '진실': 989,
#              '노력': 990,
#              '듬': 991,
#              '예고편': 992,
#              '이란': 993,
#              '취향': 994,
#              '희망': 995,
#              '무비': 996,
#              '비추': 997,
#              '아쉬운': 998,
#              '가볍': 999,
#              ...})

# %%
vars(train_data.examples[0])
# Out:
# {'text': ['야한', '장면', '기다리', '는', '것', '도', '곤욕', '이', '군'], 'label': '0'}

# %%
for i in range(len(train_data)):
    if len(train_data.examples[i].text) == 0 : print(i)

# %%
BATCH_SIZE = 64

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size = BATCH_SIZE,
    device = device,
    sort_key = lambda x : len(x.text), # 오류방지
    sort_within_batch = True # 길이에 따라 정렬
)

# %%
next(iter(train_iterator)).text
# Out:
# (tensor([[ 1559,   742,    47,   141,    72,    77,   179,   135,    62,   227,
#             136,   766,  6931,  3413,   350,    37,   147,   631,  1390,    62,
#              41,   837,  3662,    58,    92,    37,   336,  4693,   385,    81,
#              92,   104,    37,   394,  3871,   551,    41,     0,  3395,   636,
#             634,    63,  2183, 19671,    98,   163,    37,    43,    27,  1666,
#             536,  1649,   613,  1223,  3097,    32,  1074,   164,    79,    68,
#             309,   446,  1017,    27],
#          [    9,   621,    65,    95,     0,    45,  2567,    13,    78,   104,
#               4,    21,   164, 18416,    45,   107,   215,  2011,     3,     3,
#               2,    61,    36,    47,    33,   107,    10,   359,  6236,   103,
#              33,     3,   215,    12,     8,   797,  1111,    36,    44,   319,
#             568,   492,   134, 12453,  2238,    47,    65,    42,    12,    10,
#               5,  4503,    43,   437, 16104,   272,     5,    80,     9,    11,
#              62,  3711,  4901,    12],
#          [ 5642,  1132,   208,  2909,   480,     9,    99,   225,    98,   273,
#              18,   540,     0,   359,     3,    70,   261, 11037,   250,   250,
#              17,   837,    34,   109,    61,    18,  1257,   681,    13,    29,
#               3,    25,   124,    99,    18,    81,   953,   861,     3,    64,
#              12,    19,    34,  2169,  2400,  1589,    34,     2,     5,  1710,
#             139,  2481,     4,     8,   489,     6,   259,     6,   766,   113,
#              90,     2,   185,   382],
#          [  167,  1876,     5,    33,    46,  1175,    49,  1413,    78,   164,
#              24,    37, 11234,   594,    24,    21,     7,  1599,    25,    25,
#             147,  5665,    31,  4089,     5,    16,    11,   117,    98,   285,
#              42,     7,   400,    49,    99,    69,    80,   659,    11,    10,
#             215,   213,    31,   204,    18,   360,    82,     2,   146,    23,
#              76,   143,   166,   127,    75,  2081,   100,     2,    19,    45,
#             178,    17,   147,    19],
#          [    6,    91,    46, 24006,    12,   151,    38,     6,  1625,    80,
#               4,   108,     3,   477,   330,  2186,  5403,    11,     4,     4,
#             404,   310,   448,  5034,   415,    55,  1938,     5,    16,    26,
#             701,    99,     6,    44,     8,     3,    53,     6,    25,    84,
#             261,   492,   189,  1670,    25,     3,     2,  2355,     2,  3901,
#              76,   301,    12,    96,    30,    41,    18,    17,    63,   103,
#             115,    53,    27,    27],
#          [ 3331,   828,    38,   175,     0,     2,     2,    58,   191,    42,
#               5,   400,     6,    20,     2,   295,   514,   414,   600,   117,
#               5,   551,   404,     3,     2,    82,     2,   290,    28,   115,
#             551,     8,   457,     2,     6,    25,    58,     8,   177,     2,
#               4,    79,    28,  1424,    42,     6,  2177,     2,    27,    15,
#              76,    57,    85,     5,    15,  1307,  3973,   113,     9,    29,
#              29,     2,    82,    12],
#          [   53,   106,    58,   717,    21,     2,    83,    58,  1710,    67,
#               6,    70,  8130,    41,    17,    21,    38,   377,     2,     5,
#             188,   310,     5,    53,     2,     2,    17,    53,   268,     6,
#             701,     6,   101,     2,     2,    44,    58, 24691,   662,    83,
#               5,   806,  6336,  4788,     2,     2,   185,     2,    42,   191,
#              58,   220,  1059,   229,     5,    57,    53,   175,   766,    44,
#              70,    17,  1159,    79]], device='cuda:0'),
#  tensor([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#          7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#          7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7], device='cuda:0'))

# %%
import torch.nn as nn

# %% [markdown]
# - num_embeddings : 임베딩을 할 단어들의 개수. 다시 말해 단어 집합의 크기입니다.
# - embedding_dim : 임베딩 할 벡터의 차원입니다. 사용자가 정해주는 하이퍼파라미터입니다.

# %%
emb = nn.Embedding(3, 5, padding_idx = 1)
test = torch.tensor([0,1,2])

# %%
emb(test) # padding_idx에 해당하는 벡터는 0
# Out:
# tensor([[-0.3990,  0.9585, -0.1512,  1.2120, -1.1036],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [-0.1892, -0.3563,  1.2588,  0.5190,  0.8902]],
#        grad_fn=<EmbeddingBackward>)

# %%
def print_shape(name, data):
    print(f'{name} has shape {data.shape}')

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers, bidirectional=bidirectional, dropout = dropout)
        self.fc = nn.Linear(hidden_dim*2, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, text, text_lengths):
        embedded = self.dropout(self.embedding(text))
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths)
        packed_output, (hideen, cell) = self.rnn(packed_embedded)
        
        output, output_lengths = nn.utils.rnn.pad_packed_sequence(packed_output)
        
        hidden = self.dropout(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1))
        
        res = self.fc(hidden)
        return res

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 300
HIDDEN_DIM = 256
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]

# %%
model = RNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT, PAD_IDX)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'이 모델은 {count_parameters(model):,}개의 파라미터를 가지고 있다.')
# Out:
# 이 모델은 10,220,857개의 파라미터를 가지고 있다.

# %%
pretrained_embeddings = TEXT.vocab.vectors
print(pretrained_embeddings.shape)
# Out:
# torch.Size([25002, 300])

# %%
model.embedding.weight.data.shape
# Out:
# torch.Size([25002, 300])

# %%
model.embedding.weight.data.copy_(pretrained_embeddings)
# Out:
# tensor([[-0.1117, -0.4966,  0.1631,  ..., -1.4447,  0.8402, -0.8668],
#         [ 0.1032, -1.6268,  0.5729,  ...,  0.3180, -0.1626, -0.0417],
#         [ 0.0569, -0.0520,  0.2733,  ..., -0.0695, -0.1606, -0.0989],
#         ...,
#         [-1.2905,  0.2440, -0.3436,  ..., -0.2952, -0.0081,  1.0907],
#         [-1.8321, -0.9096, -0.9873,  ..., -2.3504, -0.1641, -1.5356],
#         [ 0.1700, -0.8185, -0.7213,  ..., -1.5704, -0.5734,  0.7970]])

# %%
UNK_IDX = TEXT.vocab.stoi[TEXT.unk_token]
UNK_IDX, PAD_IDX
# Out:
# (0, 1)

# %%
model.embedding.weight.data[UNK_IDX] = torch.zeros(EMBEDDING_DIM)
model.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)

print(model.embedding.weight.data)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0569, -0.0520,  0.2733,  ..., -0.0695, -0.1606, -0.0989],
#         ...,
#         [-1.2905,  0.2440, -0.3436,  ..., -0.2952, -0.0081,  1.0907],
#         [-1.8321, -0.9096, -0.9873,  ..., -2.3504, -0.1641, -1.5356],
#         [ 0.1700, -0.8185, -0.7213,  ..., -1.5704, -0.5734,  0.7970]])

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters())

# %%
criterion = nn.BCEWithLogitsLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
def binary_accuracy(preds, y):
    rounded_preds = torch.round(torch.sigmoid(preds))
